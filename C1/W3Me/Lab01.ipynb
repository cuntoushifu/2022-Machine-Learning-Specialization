# %%
import numpy as np
# %matplotlib widget
import matplotlib.pyplot as plt
from lab_utils_common import dlc, plot_data
from plt_one_addpt_onclick import plt_one_addpt_onclick

plt.style.use('./deeplearning.mplstyle')

# %%
x_train = np.array([0, 1, 2, 3, 4, 5])
y_train = np.array([0, 0, 0, 1, 1, 1])
X_train2 = np.array([[0.2, 1.5], [1, 1], [1.5, 0.5], [2, 2], [1, 2.5]])
y_train2 = np.array([0, 0, 0, 1, 1, 1])

# %%
pos = y_train == 1
neg = y_train == 0

fig, ax = plt.subplots(1, 2, figsize=(8, 3))

ax[0].scatter(x_train[pos], y_train[pos], marker='x', s=80, c='red', label='y=1')
ax[0].scatter(x_train[neg], y_train[neg], marker='o', s=100, label='y=0', facecolors='none', edgecolors=dlc['dlblue'],
              lw=3)

ax[0].set_ylim(-0.08, 1.1)
ax[0].set_ylabel('y', fontsize=12)
ax[0].set_xlabel('x', fontsize=12)
ax[0].set_title('one variable plot')
ax[0].legend()

#plot 2, two variables
plot_data(X_train2, y_train2, ax[1])
ax[1].axis([0, 4, 0, 4])
ax[1].set_ylabel('$x_1$', fontsize=12)
ax[1].set_xlabel('$x_0$', fontsize=12)
ax[1].set_title('two variable plot')
ax[1].legend()
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13108\2077453099.py in <module>
#      15
#      16 #plot 2, two variables
# ---> 17 plot_data(X_train2, y_train2, ax[1])
#      18 ax[1].axis([0, 4, 0, 4])
#      19 ax[1].set_ylabel('$x_1$', fontsize=12)
#
# E:\2022-Machine-Learning-Specialization\C1\W3Me\lab_utils_common.py in plot_data(X, y, ax, pos_label, neg_label, s, loc)
#     250
#     251     # Plot examples
# --> 252     ax.scatter(X[pos, 0], X[pos, 1], marker='x', s=s, c = 'red', label=pos_label)
#     253     ax.scatter(X[neg, 0], X[neg, 1], marker='o', s=s, label=neg_label, facecolors='none', edgecolors=dlblue, lw=3)
#     254     ax.legend(loc=loc)
#
# IndexError: boolean index did not match indexed array along dimension 0; dimension is 5 but corresponding boolean dimension is 6
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
