# %%
import numpy as np
import matplotlib.pyplot as plt
from lab_utils_multi import load_house_data, run_gradient_descent, norm_plot, plt_equal_scale, plot_cost_i_w
from lab_utils_common import dlc

np.set_printoptions(precision=2)
plt.style.use('./deeplearning.mplstyle')

# %%
X_train, y_train = load_house_data()
X_features = ['size(sqft)', 'bedrooms', 'floors', 'age']

# %%
fig, ax = plt.subplots(1, 4, figsize=(12, 3), sharey=True)
for i in range(len(ax)):
    ax[i].scatter(X_train[:, i], y_train)
    ax[i].set_xlabel(X_features[i])
ax[0].set_ylabel("Price (1000's)")
plt.show()

# %%
def show(p):
    _, _, hist = run_gradient_descent(X_train, y_train, 30, alpha=p)
    plot_cost_i_w(X_train, y_train, hist)

# %%
show(10e-7)
# Out:
# Iteration Cost          w0       w1       w2       w3       b       djdw0    djdw1    djdw2    djdw3    djdb
# ---------------------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|
#         0 9.91571e+04  5.5e-01  1.0e-03  5.2e-04  1.2e-02  3.6e-04 -5.5e+05 -1.0e+03 -5.2e+02 -1.2e+04 -3.6e+02
#         3 2.68286e+05 -2.4e-01 -4.7e-04 -2.6e-04 -8.4e-03 -1.4e-04  9.1e+05  1.7e+03  8.8e+02  2.2e+04  5.9e+02
#         6 7.30570e+05  1.1e+00  1.9e-03  9.6e-04  2.1e-02  7.3e-04 -1.5e+06 -2.8e+03 -1.4e+03 -3.5e+04 -9.9e+02
#         9 1.99414e+06 -1.1e+00 -2.1e-03 -1.1e-03 -3.3e-02 -6.7e-04  2.5e+06  4.6e+03  2.4e+03  6.0e+04  1.6e+03
#        12 5.44785e+06  2.5e+00  4.5e-03  2.3e-03  5.0e-02  1.7e-03 -4.1e+06 -7.6e+03 -3.9e+03 -9.7e+04 -2.7e+03
#        15 1.48879e+07 -3.4e+00 -6.4e-03 -3.4e-03 -9.2e-02 -2.2e-03  6.8e+06  1.3e+04  6.5e+03  1.6e+05  4.4e+03
#        18 4.06904e+07  6.4e+00  1.2e-02  5.9e-03  1.4e-01  4.2e-03 -1.1e+07 -2.1e+04 -1.1e+04 -2.7e+05 -7.3e+03
#        21 1.11217e+08 -9.8e+00 -1.8e-02 -9.6e-03 -2.5e-01 -6.3e-03  1.9e+07  3.4e+04  1.8e+04  4.4e+05  1.2e+04
#        24 3.03986e+08  1.7e+01  3.1e-02  1.6e-02  3.8e-01  1.1e-02 -3.1e+07 -5.7e+04 -2.9e+04 -7.3e+05 -2.0e+04
#        27 8.30883e+08 -2.7e+01 -5.0e-02 -2.6e-02 -6.7e-01 -1.8e-02  5.1e+07  9.3e+04  4.9e+04  1.2e+06  3.3e+04
# w,b found by gradient descent: w: [-3.83e+01 -7.05e-02 -3.68e-02 -9.28e-01], b: -0.02

# %%
show(9.9e-7)
# Out:
# Iteration Cost          w0       w1       w2       w3       b       djdw0    djdw1    djdw2    djdw3    djdb
# ---------------------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------
# w,b found by gradient descent: w: [2.53e-01 4.44e-04 2.16e-04 3.97e-03], b: 0.00

# %%
def zscore_normalize_features(X):
    mu = np.mean(X, axis=0)  #均值
    sigma = np.std(X, axis=0)  #标准差
    X_norm = (X - mu) / sigma
    return (X_norm, mu, sigma)

# %%
X_norm, mu, sigma = zscore_normalize_features(X_train)

X_mean = X_train - mu

fig, ax = plt.subplots(1, 3, figsize=(12, 3))

ax[0].scatter(X_train[:, 0], X_train[:, 3])
ax[0].set_xlabel(X_features[0])
ax[0].set_ylabel(X_features[3])
ax[0].set_title('unnormalized')
ax[0].axis('equal')

ax[1].scatter(X_mean[:, 0], X_mean[:, 3])
ax[1].set_xlabel(X_features[0])
ax[1].set_ylabel(X_features[3])
ax[1].set_title(r'X-$\mu$')
ax[1].axis('equal')

ax[2].scatter(X_norm[:, 0], X_norm[:, 3])
ax[2].set_xlabel(X_features[0])
ax[2].set_ylabel(X_features[3])
ax[2].set_title('Z-score normalized')
ax[2].axis('equal')

plt.tight_layout(rect=[0, 0.03, 1, 0.95])
fig.suptitle("distribution of features before, during, after normalization")
plt.show()

# %%
X_norm, X_mu, X_sigma = zscore_normalize_features(X_train)
print(f"X_mu={X_mu},\nX_sigma={X_sigma}")
print(f"X ptp:{np.ptp(X_train, axis=0)}")
print(f"X_norm ptp:{np.ptp(X_norm, axis=0)}")
# Out:
# X_mu=[1.42e+03 2.72e+00 1.38e+00 3.84e+01],
# X_sigma=[411.62   0.65   0.49  25.78]
# X ptp:[2.41e+03 4.00e+00 1.00e+00 9.50e+01]
# X_norm ptp:[5.85 6.14 2.06 3.69]

# %%
fig, ax = plt.subplots(1, 4, figsize=(12, 3))
for i in range(len(ax)):
    norm_plot(ax[i], X_train[:, i])
    ax[i].set_xlabel(X_features[i])
ax[0].set_ylabel("count")
fig.suptitle("distribution of feature before normalization")
plt.show()

fig, ax = plt.subplots(1, 4, figsize=(12, 3))
for i in range(len(ax)):
    norm_plot(ax[i], X_norm[:, i])
    ax[i].set_xlabel(X_features[i])
ax[0].set_ylabel("count")
fig.suptitle("distribution of feature after normalization")

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
w_norm, b_norm, hist = run_gradient_descent(X_norm, y_train, 1000, 1.0e-1, )
# Out:
# Iteration Cost          w0       w1       w2       w3       b       djdw0    djdw1    djdw2    djdw3    djdb
# ---------------------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|
#         0 5.76170e+04  8.9e+00  3.0e+00  3.3e+00 -6.0e+00  3.6e+01 -8.9e+01 -3.0e+01 -3.3e+01  6.0e+01 -3.6e+02
#       100 2.21086e+02  1.1e+02 -2.0e+01 -3.1e+01 -3.8e+01  3.6e+02 -9.2e-01  4.5e-01  5.3e-01 -1.7e-01 -9.6e-03
#       200 2.19209e+02  1.1e+02 -2.1e+01 -3.3e+01 -3.8e+01  3.6e+02 -3.0e-02  1.5e-02  1.7e-02 -6.0e-03 -2.6e-07
#       300 2.19207e+02  1.1e+02 -2.1e+01 -3.3e+01 -3.8e+01  3.6e+02 -1.0e-03  5.1e-04  5.7e-04 -2.0e-04 -6.9e-12
#       400 2.19207e+02  1.1e+02 -2.1e+01 -3.3e+01 -3.8e+01  3.6e+02 -3.4e-05  1.7e-05  1.9e-05 -6.6e-06 -2.7e-13
#       500 2.19207e+02  1.1e+02 -2.1e+01 -3.3e+01 -3.8e+01  3.6e+02 -1.1e-06  5.6e-07  6.2e-07 -2.2e-07 -2.6e-13
#       600 2.19207e+02  1.1e+02 -2.1e+01 -3.3e+01 -3.8e+01  3.6e+02 -3.7e-08  1.9e-08  2.1e-08 -7.3e-09 -2.6e-13
#       700 2.19207e+02  1.1e+02 -2.1e+01 -3.3e+01 -3.8e+01  3.6e+02 -1.2e-09  6.2e-10  6.9e-10 -2.4e-10 -2.6e-13
#       800 2.19207e+02  1.1e+02 -2.1e+01 -3.3e+01 -3.8e+01  3.6e+02 -4.1e-11  2.1e-11  2.3e-11 -8.1e-12 -2.7e-13
#       900 2.19207e+02  1.1e+02 -2.1e+01 -3.3e+01 -3.8e+01  3.6e+02 -1.4e-12  7.0e-13  7.6e-13 -2.7e-13 -2.6e-13
# w,b found by gradient descent: w: [110.56 -21.27 -32.71 -37.97], b: 363.16

# %%
def zscore_normlize_features(X):
    mu = np.mean(X_train, axis=0)
    sigma = np.std(X, axis=0)
    X_norm = (X - mu) / sigma
    return (X_norm, mu, sigma)

# %%
fig, ax = plt.subplots(1, 4, figsize=(12, 3))
for i in range(len(ax)):
    norm_plot(ax[i], X_train[:, i])
    ax[i].set_xlabel(X_features[i])
ax[0].set_ylabel("count")
fig.suptitle("distribution of features before normalization")
plt.show()

fig, ax = plt.subplots(1, 4, figsize=(12, 3))
for i in range(len(ax)):
    norm_plot(ax[i], X_norm[:, i])
    ax[0].set_ylabel("count")
fig.suptitle("distribution of features after normalization")
plt.show()

# %%
w_norm, b_norm, hist = run_gradient_descent(X_norm, y_train, 1000, 1.0e-1, )
# Out:
# Iteration Cost          w0       w1       w2       w3       b       djdw0    djdw1    djdw2    djdw3    djdb
# ---------------------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|
#         0 5.76170e+04  8.9e+00  3.0e+00  3.3e+00 -6.0e+00  3.6e+01 -8.9e+01 -3.0e+01 -3.3e+01  6.0e+01 -3.6e+02
#       100 2.21086e+02  1.1e+02 -2.0e+01 -3.1e+01 -3.8e+01  3.6e+02 -9.2e-01  4.5e-01  5.3e-01 -1.7e-01 -9.6e-03
#       200 2.19209e+02  1.1e+02 -2.1e+01 -3.3e+01 -3.8e+01  3.6e+02 -3.0e-02  1.5e-02  1.7e-02 -6.0e-03 -2.6e-07
#       300 2.19207e+02  1.1e+02 -2.1e+01 -3.3e+01 -3.8e+01  3.6e+02 -1.0e-03  5.1e-04  5.7e-04 -2.0e-04 -6.9e-12
#       400 2.19207e+02  1.1e+02 -2.1e+01 -3.3e+01 -3.8e+01  3.6e+02 -3.4e-05  1.7e-05  1.9e-05 -6.6e-06 -2.7e-13
#       500 2.19207e+02  1.1e+02 -2.1e+01 -3.3e+01 -3.8e+01  3.6e+02 -1.1e-06  5.6e-07  6.2e-07 -2.2e-07 -2.6e-13
#       600 2.19207e+02  1.1e+02 -2.1e+01 -3.3e+01 -3.8e+01  3.6e+02 -3.7e-08  1.9e-08  2.1e-08 -7.3e-09 -2.6e-13
#       700 2.19207e+02  1.1e+02 -2.1e+01 -3.3e+01 -3.8e+01  3.6e+02 -1.2e-09  6.2e-10  6.9e-10 -2.4e-10 -2.6e-13
#       800 2.19207e+02  1.1e+02 -2.1e+01 -3.3e+01 -3.8e+01  3.6e+02 -4.1e-11  2.1e-11  2.3e-11 -8.1e-12 -2.7e-13
#       900 2.19207e+02  1.1e+02 -2.1e+01 -3.3e+01 -3.8e+01  3.6e+02 -1.4e-12  7.0e-13  7.6e-13 -2.7e-13 -2.6e-13
# w,b found by gradient descent: w: [110.56 -21.27 -32.71 -37.97], b: 363.16

# %%
m = X_norm.shape[0]
yp = np.zeros(m)
for i in range(m):
    yp[i] = np.dot(X_norm[i], w_norm) + b_norm
fig, ax = plt.subplots(1, 4, figsize=(12, 3), sharey=True)
for i in range(len(ax)):
    ax[i].scatter(X_train[:, i], y_train, label='target')
    ax[i].set_xlabel(X_features[i])
    ax[i].scatter(X_train[:,i],yp,color=dlc["dlorange"],label='predict')
ax[0].set_ylabel("Price")
ax[0].legend()
fig.suptitle("target versus prediction using z-score normalized model")
plt.show()

# %%
x_house=np.array([1200,3,1,40])
