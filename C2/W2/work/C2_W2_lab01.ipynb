# %%
import numpy as np
import matplotlib.pyplot as plt
from keras import activations
from matplotlib.gridspec import GridSpec
plt.style.use('./deeplearning.mplstyle')
import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense, LeakyReLU
from keras.activations import linear, relu, sigmoid
# %matplotlib widget
from matplotlib.widgets import Slider
from lab_utils_common import dlc
from autils import plt_act_trio
from lab_utils_relu import *
import warnings
warnings.simplefilter(action='ignore', category=UserWarning)

# %% [markdown]
# <a name="2"></a>
# ## 2 - ReLU激活函数
# 本周，我们介绍了一种新的激活函数，即修正线性单元（ReLU）。
# $$ a = max(0,z) \quad\quad\text {# ReLU函数} $$

# %%
plt_act_trio()
# Out:
# Canvas(footer_visible=False, header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', …

# %% [markdown]
# <img align="right" src="./images/C2_W2_ReLu.png"     style=" width:380px; padding: 10px 20px; " >
# 在右侧的讲座示例中展示了ReLU的应用。在此示例中，派生的“意识”特征不是二进制的，而是具有连续的值范围。Sigmoid函数最适合开/关或二进制情况。ReLU提供了连续的线性关系。此外，它具有输出为零的'关闭'范围。
# "关闭"特性使ReLU成为非线性激活函数。为什么需要这个呢？让我们在下面进行检查。

# %% [markdown]
# ### Why Non-Linear Activations?
# <img align="left" src="./images/C2_W2_ReLU_Graph.png"     style=" width:250px; padding: 10px 20px; " >
# 所示的函数由线性部分组成（分段线性）。在线性部分，斜率是一致的，然后在转折点处突然改变。在转折点，添加了一个新的线性函数，
# 当与现有函数相加时，将产生新的斜率。新函数在转折点处添加，但在该点之前不会对输出产生贡献。
# 非线性激活函数负责在转折点之前和有时之后禁用输入。以下练习提供了一个更具体的例子。

# %% [markdown]
# 这个练习将使用下面的网络来解决一个回归问题，你必须模拟一个分段线性的目标：
# <img align="center" src="./images/C2_W2_ReLU_Network.png"     style=" width:650px; padding: 10px 20px; ">
# 该网络在第一层有3个单元。每个单元都将负责目标的一部分。单元0已经预先编程并固定为映射第一段。
# 你将修改单元1和2中的权重和偏差来模拟第二和第三段。输出单元也是固定的，只是简单地将第一层的输出相加。
#
# 使用下面的滑块，修改权重和偏差以匹配目标。
# 提示：从`w1`和`b1`开始，将`w2`和`b2`保持为零，直到你匹配到第二段。点击比滑动更快。如果你遇到困难，不用担心，下面的文本将更详细地描述这个问题。

# %%
_ = plt_relu_ex()
# Out:
# Canvas(footer_visible=False, header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', …

# %% [markdown]
#
# 这个练习的目标是理解ReLU的非线性行为如何提供所需的功能，即在需要时关闭函数。让我们看看这个例子是如何工作的。
# <img align="right" src="./images/C2_W2_ReLU_Plot.png"     style=" width:600px; padding: 10px 20px; ">
# 右边的图表包含了第一层单元的输出。
# 从上往下看，单元0负责标记为1的第一段。线性函数$z$和ReLU后的函数$a$都显示出来了。你可以看到ReLU在区间[0,1]后切断了函数。这是关键，因为它防止了与后续段干扰。
#
# 单元1负责第二段。在这里，ReLU保持这个单元安静，直到x超过1。由于第一个单元没有贡献，所以单元1的斜率$w^{[1]}_1$就是目标线的斜率。偏差必须调整，以保持输出在x达到1之前为负。
#
# 单元2负责第三段。ReLU再次将输出归零，直到x达到正确的值。单元的斜率$w^{[1]}_2$必须设置为使得单元1和2的和具有所需的斜率。偏差再次调整，以保持输出在x达到2之前为负。
#
# ReLU激活的"关闭"或禁用特性使模型能够将线性段拼接在一起，以模拟复杂的非线性函数。

# %% [markdown]
# # =======End of new Material===

# %% [markdown]
# ## 新的激活函数
# 本周，我们介绍了一种新的激活函数，即修正线性单元（ReLU）。

# %%
def plt_act_trio():
    X = np.linspace(-5,5,100)
    fig,ax = plt.subplots(1,3, figsize=(6,2))
    widgvis(fig)
    ax[0].plot(X,tf.keras.activations.linear(X))
    ax[0].axvline(0, lw=0.3, c="black")
    ax[0].axhline(0, lw=0.3, c="black")
    ax[0].set_title("linear")
    ax[1].plot(X,tf.keras.activations.sigmoid(X))
    ax[1].axvline(0, lw=0.3, c="black")
    ax[1].axhline(0, lw=0.3, c="black")
    ax[1].set_title("sigmoid")
    ax[2].plot(X,tf.keras.activations.relu(X))
    ax[2].axhline(0, lw=0.3, c="black")
    ax[2].axvline(0, lw=0.3, c="black")
    ax[2].set_title("relu")
    fig.suptitle("Common Activation Functions", fontsize=14)
    fig.tight_layout(pad=0.2)
    plt.show()
plt_act_trio()
# Out:
# Canvas(footer_visible=False, header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', …

# %% [markdown]
# <right images>
#   在右边的例子中展示了ReLU的应用。在这个例子中，"awareness"特性不是二进制的，而是有一个从0到更大值的范围。Sigmoid函数最适合开/关或二进制情况。ReLU提供了一个线性关系，并且有一个'关闭'范围，其中输出为零。"关闭"特性使ReLU成为一个非线性激活函数。为什么需要这个呢？让我们通过下面的例子来检查。

# %%
X = np.linspace(0,2*np.pi, 100)
y = np.cos(X)+1
y[50:100]=0
fig,ax = plt.subplots(1,1, figsize=(2,2))
widgvis(fig)
ax.plot(X,y)
plt.show()
# Out:
# Canvas(footer_visible=False, header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', …

# %%
w10 = np.array([[-1]])
b10 = np.array([2.6])
d10 = Dense(1, activation = "linear", input_shape = (1,), weights=[w10,b10])
z10 = d10(X.reshape(-1,1))
a10 = relu(z10)

# %%
def plt_act1(y,z,a):
    fig,ax = plt.subplots(1,3, figsize=(6,2.5))
    widgvis(fig)
    ax[0].plot(X,y,label="target")
    ax[0].axvline(0, lw=0.3, c="black")
    ax[0].axhline(0, lw=0.3, c="black")
    ax[0].set_title("y - target")
    ax[1].plot(X,y, label="target")
    ax[1].plot(X,z, c=dlc["dldarkred"],label="z")
    ax[1].axvline(0, lw=0.3, c="black")
    ax[1].axhline(0, lw=0.3, c="black")
    ax[1].set_title("z = wX+b")
    ax[1].legend(loc="upper center")
    ax[2].plot(X,y, label="target")
    ax[2].plot(X,a, c=dlc["dldarkred"],label="ReLu(z)")
    ax[2].axhline(0, lw=0.3, c="black")
    ax[2].axvline(0, lw=0.3, c="black")
    ax[2].set_title("with relu")
    ax[2].legend()
    fig.suptitle("Role of Activation", fontsize=14)
    fig.tight_layout(pad=0.2)
    return(ax)


def plt_add_notation(ax):
    ax[1].annotate(text = "matches\n here", xy =(1.5,1.0), 
                   xytext = (0.1,-1.5), fontsize=10,
                  arrowprops=dict(facecolor=dlc["dlpurple"],width=2, headwidth=8))
    ax[1].annotate(text = "but not\n here", xy =(5,-2.5), 
                   xytext = (1,-3), fontsize=10,
                  arrowprops=dict(facecolor=dlc["dlpurple"],width=2, headwidth=8))
    ax[2].annotate(text = "ReLu\n 'off'", xy =(2.6,0), 
                   xytext = (0.1,0.1), fontsize=10,
                  arrowprops=dict(facecolor=dlc["dlpurple"],width=2, headwidth=8))
    
ax = plt_act1(y,z10,a10)
plt_add_notation(ax)
# Out:
# Canvas(footer_visible=False, header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', …

# %%
X = np.linspace(0,2*np.pi, 100)
y = np.cos(X)+1
y[0:49]=0
fig,ax = plt.subplots(1,1, figsize=(2,2))
widgvis(fig)
ax.plot(X,y)
plt.show()
# Out:
# Canvas(footer_visible=False, header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', …

# %%
w11 = np.array([[1]])
b11 = np.array([-3.7])
d11 = Dense(1, activation = "linear", input_shape = (1,), weights=[w11,b11])
z11 = d11(X.reshape(-1,1))
a11 = relu(z11)
plt_act1(y,z11,a11)
# Out:
# array([<AxesSubplot:title={'center':'y - target'}>,
#        <AxesSubplot:title={'center':'z = wX+b'}>,
#        <AxesSubplot:title={'center':'with relu'}>], dtype=object)
# Canvas(footer_visible=False, header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', …

# %%
X = np.linspace(0,2*np.pi, 100)
y = np.cos(X)+1
X=X.reshape(-1,1)
yhat = relu(d10(X)) + relu(d11(X))

fig,ax = plt.subplots(1,2, figsize=(4,2))
widgvis(fig)
ax[0].plot(X,y)
ax[1].plot(X,y)
ax[1].plot(X,yhat)
plt.show()
# Out:
# Canvas(footer_visible=False, header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', …

# %%
X=X.reshape(-1,1)
yhat = relu(d10(X)) + relu(d11(X))
fig,ax = plt.subplots(1,1, figsize=(2,2))
widgvis(fig)
ax.plot(X,y)
ax.plot(X,yhat)
plt.show()
# Out:
# Canvas(footer_visible=False, header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', …

# %%
model=Sequential([
    d11
])
yhat = model.predict(X.reshape(-1,1))
fig,ax = plt.subplots(1,1, figsize=(2,2))
widgvis(fig)
ax.plot(X,y)
ax.plot(X,yhat)
plt.show()
# Out:
# 4/4 [==============================] - 0s 2ms/step
# Canvas(footer_visible=False, header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', …

# %%
model = Sequential(
    [ 
        d10,
        keras.layers.Activation(activations.relu),
        d11,
        keras.layers.Activation(activations.relu),
        Dense(1, activation = 'linear')
    ]
)
model.compile(
    loss=tf.keras.losses.MeanSquaredError(),
    optimizer=tf.keras.optimizers.Adam(0.1),
)

model.fit(
    X,y,
    epochs=1000
)
# Out:
# Epoch 1/1000
# 4/4 [==============================] - 1s 4ms/step - loss: 1.3358
# Epoch 2/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.7719
# Epoch 3/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5328
# Epoch 4/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5127
# Epoch 5/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5625
# Epoch 6/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5745
# Epoch 7/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5492
# Epoch 8/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5170
# Epoch 9/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5148
# Epoch 10/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5238
# Epoch 11/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5231
# Epoch 12/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5079
# Epoch 13/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5077
# Epoch 14/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5091
# Epoch 15/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5130
# Epoch 16/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5106
# Epoch 17/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5050
# Epoch 18/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5073
# Epoch 19/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5076
# Epoch 20/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5061
# Epoch 21/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5071
# Epoch 22/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5111
# Epoch 23/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5167
# Epoch 24/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5165
# Epoch 25/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5097
# Epoch 26/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5102
# Epoch 27/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5092
# Epoch 28/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5094
# Epoch 29/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5074
# Epoch 30/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5055
# Epoch 31/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5116
# Epoch 32/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5149
# Epoch 33/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5080
# Epoch 34/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5028
# Epoch 35/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5079
# Epoch 36/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5061
# Epoch 37/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5052
# Epoch 38/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5053
# Epoch 39/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5145
# Epoch 40/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5242
# Epoch 41/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5112
# Epoch 42/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5041
# Epoch 43/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5079
# Epoch 44/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5089
# Epoch 45/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5099
# Epoch 46/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5090
# Epoch 47/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5084
# Epoch 48/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5113
# Epoch 49/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5061
# Epoch 50/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5102
# Epoch 51/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5135
# Epoch 52/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5085
# Epoch 53/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5066
# Epoch 54/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5048
# Epoch 55/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5043
# Epoch 56/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5080
# Epoch 57/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.
1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5138
# Epoch 921/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5155
# Epoch 922/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5098
# Epoch 923/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5074
# Epoch 924/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5090
# Epoch 925/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5078
# Epoch 926/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5066
# Epoch 927/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5057
# Epoch 928/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5059
# Epoch 929/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5047
# Epoch 930/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5047
# Epoch 931/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5110
# Epoch 932/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5121
# Epoch 933/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5048
# Epoch 934/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5077
# Epoch 935/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5068
# Epoch 936/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5046
# Epoch 937/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5069
# Epoch 938/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5082
# Epoch 939/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5068
# Epoch 940/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5071
# Epoch 941/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5070
# Epoch 942/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5079
# Epoch 943/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5044
# Epoch 944/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5119
# Epoch 945/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5130
# Epoch 946/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5021
# Epoch 947/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5119
# Epoch 948/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5316
# Epoch 949/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5337
# Epoch 950/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5409
# Epoch 951/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5127
# Epoch 952/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4999
# Epoch 953/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5260
# Epoch 954/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5212
# Epoch 955/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5017
# Epoch 956/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5184
# Epoch 957/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5143
# Epoch 958/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5127
# Epoch 959/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5082
# Epoch 960/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5048
# Epoch 961/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5080
# Epoch 962/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5051
# Epoch 963/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5047
# Epoch 964/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5086
# Epoch 965/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5096
# Epoch 966/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5107
# Epoch 967/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5223
# Epoch 968/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5121
# Epoch 969/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5038
# Epoch 970/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5187
# Epoch 971/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5126
# Epoch 972/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5072
# Epoch 973/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5121
# Epoch 974/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5148
# Epoch 975/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5125
# Epoch 976/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5187
# Epoch 977/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5212
# Epoch 978/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5087
# Epoch 979/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5046
# Epoch 980/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5070
# Epoch 981/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5057
# Epoch 982/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5077
# Epoch 983/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5071
# Epoch 984/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5056
# Epoch 985/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5077
# Epoch 986/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5080
# Epoch 987/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5103
# Epoch 988/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5159
# Epoch 989/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5199
# Epoch 990/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5031
# Epoch 991/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5244
# Epoch 992/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5329
# Epoch 993/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5170
# Epoch 994/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5176
# Epoch 995/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5191
# Epoch 996/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5066
# Epoch 997/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5118
# Epoch 998/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5321
# Epoch 999/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5267
# Epoch 1000/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5169

# %%
model = Sequential(
    [ 
        Dense(1,activation="relu", name = 'l1'),
        Dense(1,activation="linear", name = 'l2')
    ]
)
model.compile(
    loss=tf.keras.losses.MeanSquaredError(),
    optimizer=tf.keras.optimizers.Adam(0.01),
)

model.fit(
    X,y,
    epochs=10
)
# Out:
# Epoch 1/10
# 4/4 [==============================] - 1s 2ms/step - loss: 1.5018
# Epoch 2/10
# 4/4 [==============================] - 0s 2ms/step - loss: 1.4238
# Epoch 3/10
# 4/4 [==============================] - 0s 2ms/step - loss: 1.3495
# Epoch 4/10
# 4/4 [==============================] - 0s 3ms/step - loss: 1.2826
# Epoch 5/10
# 4/4 [==============================] - 0s 2ms/step - loss: 1.2172
# Epoch 6/10
# 4/4 [==============================] - 0s 3ms/step - loss: 1.1555
# Epoch 7/10
# 4/4 [==============================] - 0s 2ms/step - loss: 1.0970
# Epoch 8/10
# 4/4 [==============================] - 0s 2ms/step - loss: 1.0444
# Epoch 9/10
# 4/4 [==============================] - 0s 2ms/step - loss: 0.9947
# Epoch 10/10
# 4/4 [==============================] - 0s 3ms/step - loss: 0.9498

# %%
yhat = model.predict(X)
yhat[0:5]
# Out:
# 4/4 [==============================] - 0s 2ms/step
# array([[0.37],
#        [0.37],
#        [0.37],
#        [0.37],
#        [0.37]], dtype=float32)

# %%
fig,ax = plt.subplots(1,1, figsize=(4,4))
ax.plot(X,y)
ax.plot(X,yhat, c=dlc["dldarkred"])
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
l1 = model.get_layer('l1')
l2 = model.get_layer('l2')

# %%
l1.get_weights()
# Out:
# [array([[-1.35]], dtype=float32), array([0.], dtype=float32)]

# %%
l2.get_weights()
# Out:
# [array([[-0.09]], dtype=float32), array([0.37], dtype=float32)]

# %%
l1 = model.get_layer('l1')
l2 = model.get_layer('l2')
l1.get_weights()
l2.get_weights()

w1 = np.array([[-1]])
b1 = np.array([1])
l1.set_weights([w1,b1])

w2 = np.array([[1]])
b2 = np.array([0])
l2.set_weights([w2,b2])
model.fit(
    X,y,
    epochs=100
)
# Out:
# Epoch 1/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.2350
# Epoch 2/100
# 4/4 [==============================] - 0s 3ms/step - loss: 1.1340
# Epoch 3/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.0245
# Epoch 4/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.9169
# Epoch 5/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.8040
# Epoch 6/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7087
# Epoch 7/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6210
# Epoch 8/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5578
# Epoch 9/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5271
# Epoch 10/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5238
# Epoch 11/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5176
# Epoch 12/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5001
# Epoch 13/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4839
# Epoch 14/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4704
# Epoch 15/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4616
# Epoch 16/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4542
# Epoch 17/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4461
# Epoch 18/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4383
# Epoch 19/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4305
# Epoch 20/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4219
# Epoch 21/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4146
# Epoch 22/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4095
# Epoch 23/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4026
# Epoch 24/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3977
# Epoch 25/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3922
# Epoch 26/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3877
# Epoch 27/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3834
# Epoch 28/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3805
# Epoch 29/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3764
# Epoch 30/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3743
# Epoch 31/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3716
# Epoch 32/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3688
# Epoch 33/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3660
# Epoch 34/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3643
# Epoch 35/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3620
# Epoch 36/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3607
# Epoch 37/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3594
# Epoch 38/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3582
# Epoch 39/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3567
# Epoch 40/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3558
# Epoch 41/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3546
# Epoch 42/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3530
# Epoch 43/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3519
# Epoch 44/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3511
# Epoch 45/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3506
# Epoch 46/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3504
# Epoch 47/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3498
# Epoch 48/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3492
# Epoch 49/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3492
# Epoch 50/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3486
# Epoch 51/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3486
# Epoch 52/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3483
# Epoch 53/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3484
# Epoch 54/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3481
# Epoch 55/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3479
# Epoch 56/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3479
# Epoch 57/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3478
# Epoch 58/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3476
# Epoch 59/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3473
# Epoch 60/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3471
# Epoch 61/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3471
# Epoch 62/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3469
# Epoch 63/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3467
# Epoch 64/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3469
# Epoch 65/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3465
# Epoch 66/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3465
# Epoch 67/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3466
# Epoch 68/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3467
# Epoch 69/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3466
# Epoch 70/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3465
# Epoch 71/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3465
# Epoch 72/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3465
# Epoch 73/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3465
# Epoch 74/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3465
# Epoch 75/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3465
# Epoch 76/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3465
# Epoch 77/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3467
# Epoch 78/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3467
# Epoch 79/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3466
# Epoch 80/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3465
# Epoch 81/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3465
# Epoch 82/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3465
# Epoch 83/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3465
# Epoch 84/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3466
# Epoch 85/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3466
# Epoch 86/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3466
# Epoch 87/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3465
# Epoch 88/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3468
# Epoch 89/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3466
# Epoch 90/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3466
# Epoch 91/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3466
# Epoch 92/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3465
# Epoch 93/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3465
# Epoch 94/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3466
# Epoch 95/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3466
# Epoch 96/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3464
# Epoch 97/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3464
# Epoch 98/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3468
# Epoch 99/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3466
# Epoch 100/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3467

# %%
l2.set_weights([w2,b2])

# %%
yhat = model.predict(X)
fig,ax = plt.subplots(1,1, figsize=(4,4))
ax.plot(X,y)
ax.plot(X,yhat, c=dlc["dldarkred"])
plt.show()
# Out:
# 4/4 [==============================] - 0s 2ms/step
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## 2-D

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib as mpl
import warnings
from matplotlib import cm
from matplotlib.patches import FancyArrowPatch
from matplotlib.colors import ListedColormap, LinearSegmentedColormap
import matplotlib.colors as colors
from lab_utils_common import dlc
dkcolors = plt.cm.Paired((1,3,7,9,5,11))
ltcolors = plt.cm.Paired((0,2,6,8,4,10))
dkcolors_map = mpl.colors.ListedColormap(dkcolors)
ltcolors_map = mpl.colors.ListedColormap(ltcolors)

# %%
def plt_mc_data(ax, X, y, classes,  class_labels=None, map=plt.cm.Paired, 
                legend=False, size=50, m='o', equal_xy = False):
    """ Plot multiclass data. Note, if equal_xy is True, setting ylim on the plot may not work """
    for i in range(classes):
        idx = np.where(y == i)
        col = len(idx[0])*[i]
        label = class_labels[i] if class_labels else "c{}".format(i)
        ax.scatter(X[idx, 0], X[idx, 1],  marker=m,
                    c=col, vmin=0, vmax=map.N, cmap=map,
                    s=size, label=label)
    if legend: ax.legend()
    if equal_xy: ax.axis("equal")

def plt_mc(X_train,y_train,classes):
    css = np.unique(y_train)
    fig,ax = plt.subplots(1,1,figsize=(3,3))
    fig.canvas.toolbar_visible = False
    fig.canvas.header_visible = False
    fig.canvas.footer_visible = False
    plt_mc_data(ax, X_train,y_train,classes, map=dkcolors_map, legend=True, size=10, equal_xy = False)
    ax.set_title("Multiclass Data")
    ax.set_xlabel("x0")
    ax.set_ylabel("x1")
    return(ax)
    
def plot_cat_decision_boundary_mc(ax, X, predict , class_labels=None, legend=False, vector=True):

    # create a mesh to points to plot
    x_min, x_max = X[:, 0].min(), X[:, 0].max()
    y_min, y_max = X[:, 1].min(), X[:, 1].max()
    h = max(x_max-x_min, y_max-y_min)/200
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                         np.arange(y_min, y_max, h))
    points = np.c_[xx.ravel(), yy.ravel()]
    #print("points", points.shape)
    #print("xx.shape", xx.shape)

    #make predictions for each point in mesh
    if vector:
        Z = predict(points)
    else:
        Z = np.zeros((len(points),))
        for i in range(len(points)):
            Z[i] = predict(points[i].reshape(1,2))
    Z = Z.reshape(xx.shape)

    #contour plot highlights boundaries between values - classes in this case
    ax.contour(xx, yy, Z, linewidths=1) 
    #ax.axis('tight')

# %%
X = np.random.rand(300, 2)
y = np.sqrt( X[:,0]**2 + X[:,1]**2 ) < 0.6
#y = np.logical_and( X[:,0] < 0.5, X[:,1] < 0.5 ).astype(int)
y.shape
plt_mc(X,y,2,)
# Out:
# <AxesSubplot:title={'center':'Multiclass Data'}, xlabel='x0', ylabel='x1'>
# Canvas(footer_visible=False, header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', …

# %%
model = Sequential(
    [ 
        Dense(2,activation="relu",    name = 'l1'),
        Dense(1,activation="sigmoid", name = 'l2')
    ]
)

model.compile(
    loss=tf.keras.losses.MeanSquaredError(),
    optimizer=tf.keras.optimizers.Adam(0.01),
)

model.fit(
    X,y,
    epochs=150
)
# Out:
# Epoch 1/150
# 10/10 [==============================] - 1s 2ms/step - loss: 0.2326
# Epoch 2/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2075
# Epoch 3/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1909
# Epoch 4/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1825
# Epoch 5/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1774
# Epoch 6/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1740
# Epoch 7/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1696
# Epoch 8/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1650
# Epoch 9/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1597
# Epoch 10/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1542
# Epoch 11/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1483
# Epoch 12/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1421
# Epoch 13/150
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1357
# Epoch 14/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1299
# Epoch 15/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1237
# Epoch 16/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1180
# Epoch 17/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1125
# Epoch 18/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1072
# Epoch 19/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1022
# Epoch 20/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0975
# Epoch 21/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0931
# Epoch 22/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0892
# Epoch 23/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0854
# Epoch 24/150
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0820
# Epoch 25/150
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0788
# Epoch 26/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0759
# Epoch 27/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0731
# Epoch 28/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0706
# Epoch 29/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0682
# Epoch 30/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0660
# Epoch 31/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0641
# Epoch 32/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0621
# Epoch 33/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0603
# Epoch 34/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0589
# Epoch 35/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0573
# Epoch 36/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0559
# Epoch 37/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0545
# Epoch 38/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0532
# Epoch 39/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0521
# Epoch 40/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0511
# Epoch 41/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0499
# Epoch 42/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0493
# Epoch 43/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0481
# Epoch 44/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0475
# Epoch 45/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0465
# Epoch 46/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0458
# Epoch 47/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0450
# Epoch 48/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0445
# Epoch 49/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0438
# Epoch 50/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0430
# Epoch 51/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0424
# Epoch 52/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0419
# Epoch 53/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0414
# Epoch 54/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0410
# Epoch 55/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0407
# Epoch 56/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0399
# Epoch 57/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0395
# Epoch 58/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0391
# Epoch 59/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0387
# Epoch 60/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0382
# Epoch 61/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0380
# Epoch 62/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0376
# Epoch 63/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0371
# Epoch 64/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0371
# Epoch 65/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0366
# Epoch 66/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0362
# Epoch 67/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0359
# Epoch 68/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0355
# Epoch 69/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0352
# Epoch 70/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0349
# Epoch 71/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0344
# Epoch 72/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0341
# Epoch 73/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0338
# Epoch 74/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0336
# Epoch 75/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0332
# Epoch 76/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0329
# Epoch 77/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0325
# Epoch 78/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0323
# Epoch 79/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0329
# Epoch 80/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0322
# Epoch 81/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0314
# Epoch 82/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0312
# Epoch 83/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0307
# Epoch 84/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0303
# Epoch 85/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0300
# Epoch 86/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0297
# Epoch 87/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0294
# Epoch 88/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0291
# Epoch 89/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0290
# Epoch 90/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0289
# Epoch 91/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0282
# Epoch 92/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0279
# Epoch 93/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0279
# Epoch 94/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0273
# Epoch 95/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0271
# Epoch 96/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0268
# Epoch 97/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0265
# Epoch 98/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0262
# Epoch 99/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0261
# Epoch 100/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0255
# Epoch 101/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0254
# Epoch 102/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0254
# Epoch 103/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0252
# Epoch 104/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0246
# Epoch 105/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0246
# Epoch 106/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0246
# Epoch 107/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0242
# Epoch 108/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0236
# Epoch 109/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0236
# Epoch 110/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0234
# Epoch 111/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0228
# Epoch 112/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0230
# Epoch 113/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0232
# Epoch 114/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0226
# Epoch 115/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0223
# Epoch 116/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0221
# Epoch 117/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0219
# Epoch 118/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0220
# Epoch 119/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0217
# Epoch 120/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0214
# Epoch 121/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0213
# Epoch 122/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0211
# Epoch 123/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0209
# Epoch 124/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0209
# Epoch 125/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0207
# Epoch 126/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0207
# Epoch 127/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0203
# Epoch 128/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0206
# Epoch 129/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0203
# Epoch 130/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0201
# Epoch 131/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0199
# Epoch 132/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0199
# Epoch 133/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0198
# Epoch 134/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0196
# Epoch 135/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0195
# Epoch 136/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0195
# Epoch 137/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0194
# Epoch 138/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0193
# Epoch 139/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0192
# Epoch 140/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0191
# Epoch 141/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0190
# Epoch 142/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0188
# Epoch 143/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0188
# Epoch 144/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0190
# Epoch 145/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0187
# Epoch 146/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0187
# Epoch 147/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0188
# Epoch 148/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0183
# Epoch 149/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0184
# Epoch 150/150
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0184

# %%
ax = plt_mc(X,y,2,)
predict = lambda  x: (model.predict(x) > 0.5).astype(int)
plot_cat_decision_boundary_mc(ax, X, predict, legend = True, vector=True)
# Out:
# 1244/1244 [==============================] - 1s 1ms/step
# Canvas(footer_visible=False, header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', …

# %%
l1 = model.get_layer("l1")
W1,b1 = l1.get_weights()
l2 = model.get_layer("l2")
W2,b2 = l2.get_weights()
print(W1,b1)
print(W2,b2)
# Out:
# [[ 3.94 -2.59]
#  [ 3.13  2.45]] [-1.97 -0.65]
# [[-4.05]
#  [-3.36]] [3.13]

# %%
x0 = np.array([0.4,0.60])
np.dot( np.dot(x0,W1) + b1, W2) + b2
# Out:
# array([-2.17])

# %%
## Example

# %%
import time
import warnings

import numpy as np
import matplotlib.pyplot as plt

from sklearn import cluster, datasets, mixture
from sklearn.neighbors import kneighbors_graph
from sklearn.preprocessing import StandardScaler
from itertools import cycle, islice

np.random.seed(0)

# ============
# Generate datasets. We choose the size big enough to see the scalability
# of the algorithms, but not too big to avoid too long running times
# ============
n_samples = 500
noisy_circles = datasets.make_circles(n_samples=n_samples, factor=0.5, noise=0.05)
noisy_moons = datasets.make_moons(n_samples=n_samples, noise=0.05)
blobs = datasets.make_blobs(n_samples=n_samples, random_state=8)
no_structure = np.random.rand(n_samples, 2), None

# Anisotropicly distributed data
random_state = 170
X, y = datasets.make_blobs(n_samples=n_samples, random_state=random_state)
transformation = [[0.6, -0.6], [-0.4, 0.8]]
X_aniso = np.dot(X, transformation)
aniso = (X_aniso, y)

# blobs with varied variances
varied = datasets.make_blobs(
    n_samples=n_samples, cluster_std=[1.0, 2.5, 0.5], random_state=random_state
)

# ============
# Set up cluster parameters
# ============
plt.figure(figsize=(9 * 2 + 3, 13))
plt.subplots_adjust(
    left=0.02, right=0.98, bottom=0.001, top=0.95, wspace=0.05, hspace=0.01
)

plot_num = 1

default_base = {
    "quantile": 0.3,
    "eps": 0.3,
    "damping": 0.9,
    "preference": -200,
    "n_neighbors": 3,
    "n_clusters": 3,
    "min_samples": 7,
    "xi": 0.05,
    "min_cluster_size": 0.1,
}

datasets = [
    (
        noisy_circles,
        {
            "damping": 0.77,
            "preference": -240,
            "quantile": 0.2,
            "n_clusters": 2,
            "min_samples": 7,
            "xi": 0.08,
        },
    ),
    (
        noisy_moons,
        {
            "damping": 0.75,
            "preference": -220,
            "n_clusters": 2,
            "min_samples": 7,
            "xi": 0.1,
        },
    ),
    (
        varied,
        {
            "eps": 0.18,
            "n_neighbors": 2,
            "min_samples": 7,
            "xi": 0.01,
            "min_cluster_size": 0.2,
        },
    ),
    (
        aniso,
        {
            "eps": 0.15,
            "n_neighbors": 2,
            "min_samples": 7,
            "xi": 0.1,
            "min_cluster_size": 0.2,
        },
    ),
    (blobs, {"min_samples": 7, "xi": 0.1, "min_cluster_size": 0.2}),
    (no_structure, {}),
]

datasets = [
    (no_structure, {}),
]

for i_dataset, (dataset, algo_params) in enumerate(datasets):
    # update parameters with dataset-specific values
    params = default_base.copy()
    params.update(algo_params)

    X, y = dataset

    # normalize dataset for easier parameter selection
    X = StandardScaler().fit_transform(X)

    # estimate bandwidth for mean shift
    bandwidth = cluster.estimate_bandwidth(X, quantile=params["quantile"])

    # connectivity matrix for structured Ward
    connectivity = kneighbors_graph(
        X, n_neighbors=params["n_neighbors"], include_self=False
    )
    # make connectivity symmetric
    connectivity = 0.5 * (connectivity + connectivity.T)

    # ============
    # Create cluster objects
    # ============
    ms = cluster.MeanShift(bandwidth=bandwidth, bin_seeding=True)
    two_means = cluster.MiniBatchKMeans(n_clusters=params["n_clusters"])
    ward = cluster.AgglomerativeClustering(
        n_clusters=params["n_clusters"], linkage="ward", connectivity=connectivity
    )
    spectral = cluster.SpectralClustering(
        n_clusters=params["n_clusters"],
        eigen_solver="arpack",
        affinity="nearest_neighbors",
    )
    dbscan = cluster.DBSCAN(eps=params["eps"])
    optics = cluster.OPTICS(
        min_samples=params["min_samples"],
        xi=params["xi"],
        min_cluster_size=params["min_cluster_size"],
    )
    affinity_propagation = cluster.AffinityPropagation(
        damping=params["damping"], preference=params["preference"], random_state=0
    )
    average_linkage = cluster.AgglomerativeClustering(
        linkage="average",
        affinity="cityblock",
        n_clusters=params["n_clusters"],
        connectivity=connectivity,
    )
    birch = cluster.Birch(n_clusters=params["n_clusters"])
    gmm = mixture.GaussianMixture(
        n_components=params["n_clusters"], covariance_type="full"
    )

    clustering_algorithms = (
        ("MiniBatch\nKMeans", two_means),
        ("Affinity\nPropagation", affinity_propagation),
        ("MeanShift", ms),
        ("Spectral\nClustering", spectral),
        ("Ward", ward),
        ("Agglomerative\nClustering", average_linkage),
        ("DBSCAN", dbscan),
        ("OPTICS", optics),
        ("BIRCH", birch),
        ("Gaussian\nMixture", gmm),
    )

    for name, algorithm in clustering_algorithms:
        t0 = time.time()

        # catch warnings related to kneighbors_graph
        with warnings.catch_warnings():
            warnings.filterwarnings(
                "ignore",
                message="the number of connected components of the "
                + "connectivity matrix is [0-9]{1,2}"
                + " > 1. Completing it to avoid stopping the tree early.",
                category=UserWarning,
            )
            warnings.filterwarnings(
                "ignore",
                message="Graph is not fully connected, spectral embedding"
                + " may not work as expected.",
                category=UserWarning,
            )
            print(X.shape,algorithm)
            algorithm.fit(X)

        t1 = time.time()
        if hasattr(algorithm, "labels_"):
            y_pred = algorithm.labels_.astype(int)
        else:
            y_pred = algorithm.predict(X)

        plt.subplot(len(datasets), len(clustering_algorithms), plot_num)
        if i_dataset == 0:
            plt.title(name, size=18)

        colors = np.array(
            list(
                islice(
                    cycle(
                        [
                            "#377eb8",
                            "#ff7f00",
                            "#4daf4a",
                            "#f781bf",
                            "#a65628",
                            "#984ea3",
                            "#999999",
                            "#e41a1c",
                            "#dede00",
                        ]
                    ),
                    int(max(y_pred) + 1),
                )
            )
        )
        # add black color for outliers (if any)
        colors = np.append(colors, ["#000000"])
        plt.scatter(X[:, 0], X[:, 1], s=10, color=colors[y_pred])

        plt.xlim(-2.5, 2.5)
        plt.ylim(-2.5, 2.5)
        plt.xticks(())
        plt.yticks(())
        plt.text(
            0.99,
            0.01,
            ("%.2fs" % (t1 - t0)).lstrip("0"),
            transform=plt.gca().transAxes,
            size=15,
            horizontalalignment="right",
        )
        plot_num += 1

plt.show()
# Out:
# (500, 2) MiniBatchKMeans(n_clusters=3)
# (500, 2) AffinityPropagation(damping=0.9, preference=-200, random_state=0)
# (500, 2) MeanShift(bandwidth=1.321267758400405, bin_seeding=True)
# (500, 2) SpectralClustering(affinity='nearest_neighbors', eigen_solver='arpack',
#                    n_clusters=3)
# (500, 2) AgglomerativeClustering(connectivity=<500x500 sparse matrix of type '<class 'numpy.float64'>'
# 	with 1892 stored elements in Compressed Sparse Row format>,
#                         n_clusters=3)
# (500, 2) AgglomerativeClustering(affinity='cityblock',
#                         connectivity=<500x500 sparse matrix of type '<class 'numpy.float64'>'
# 	with 1892 stored elements in Compressed Sparse Row format>,
#                         linkage='average', n_clusters=3)
# (500, 2) DBSCAN(eps=0.3)
# (500, 2) OPTICS(min_cluster_size=0.1, min_samples=7)
# (500, 2) Birch()
# (500, 2) GaussianMixture(n_components=3)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
